# %% [markdown]
# ## ***COVID 19 Data Analysis Project - Ardent Computech***
# ------------------------------------------

# %% [markdown]
# ***Importing the Modules in the Colaboratory***
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# ***Importing Covid 19 Dataset***
#
# ---

# %%
corona_dataset_csv = pd.read_csv('covid19_Confirmed_dataset.csv')
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %% [markdown]
# ***Checking the Shape of the Dataframe***
#
# ---

# %%
corona_dataset_csv.shape
# Out:
# (266, 104)

# %%
columns = corona_dataset_csv.columns
columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '4/21/20', '4/22/20', '4/23/20', '4/24/20', '4/25/20', '4/26/20',
#        '4/27/20', '4/28/20', '4/29/20', '4/30/20'],
#       dtype='object', length=104)

# %% [markdown]
# ***Deleting the Useless Columns from the Dataset***
#
# ---

# %%
#Latitude and Longitude are not important features for us here
corona_dataset_csv.drop(["Lat",
                        "Long"],
                        axis=1,
                        #default value, annotation axis=0 which is equal to rows
                        inplace = True   #will change the corona dataset too
                        )

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %% [markdown]
# ***Aggregating the rows by the country***
#
# ---

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()
# Out:
# <ipython-input-181-06cc07508d05>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# ***Visualizing data related to a country: "China"***
#
# ---

# %%
corona_dataset_aggregated.loc["China"]
# Out:
# 1/22/20      548
# 1/23/20      643
# 1/24/20      920
# 1/25/20     1406
# 1/26/20     2075
#            ...
# 4/26/20    83912
# 4/27/20    83918
# 4/28/20    83940
# 4/29/20    83944
# 4/30/20    83956
# Name: China, Length: 100, dtype: int64

# %% [markdown]
# ***Plotting the Graphs***
#
# ---

# %%
corona_dataset_aggregated.loc['China'].plot()
# Out:
# <Axes: >

# %%
corona_dataset_aggregated.loc['Egypt'].plot()
plt.legend()

# %%
corona_dataset_aggregated.loc['China'].plot()
corona_dataset_aggregated.loc['Italy'].plot()
corona_dataset_aggregated.loc['Spain'].plot()
plt.legend()

# %% [markdown]
# ***Showing the Increasing of Cases in First 20 Days of the Month***
#
# ---

# %%
corona_dataset_aggregated.loc['China'][:5].plot()
# Out:
# <Axes: >

# %% [markdown]
# ***Calculating the First Derivative of the Curve***
#
# ---

# %% [markdown]
# **This plot shows us the change in infection rate day by day and what we are looking for is the maximum number.**

# %%
corona_dataset_aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %% [markdown]
# ***Finding the Maximum Infection Rate in China***
#
# ---

# %%
corona_dataset_aggregated.loc["China"].diff().max()
#In only 24 hrs, the difference was 15136
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc["Italy"].diff().max()
#In only 24 hrs, the difference was 6557
# Out:
# 6557.0

# %%
corona_dataset_aggregated.loc["Spain"].diff().max()
#In only 24 hrs, the difference was 9630
# Out:
# 9630.0

# %% [markdown]
# ***Finding the Maximum Infection Rate of All Countries***
#
# ---

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for c in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
max_infection_rates
# Out:
# [232.0,
#  34.0,
#  199.0,
#  43.0,
#  5.0,
#  6.0,
#  291.0,
#  134.0,
#  497.0,
#  1321.0,
#  105.0,
#  7.0,
#  301.0,
#  641.0,
#  12.0,
#  1485.0,
#  2454.0,
#  4.0,
#  19.0,
#  1.0,
#  104.0,
#  92.0,
#  7.0,
#  7502.0,
#  26.0,
#  137.0,
#  41.0,
#  21.0,
#  6.0,
#  45.0,
#  31.0,
#  203.0,
#  2778.0,
#  31.0,
#  21.0,
#  1138.0,
#  15136.0,
#  353.0,
#  1.0,
#  57.0,
#  81.0,
#  37.0,
#  113.0,
#  96.0,
#  63.0,
#  58.0,
#  381.0,
#  391.0,
#  99.0,
#  156.0,
#  5.0,
#  371.0,
#  11536.0,
#  269.0,
#  32.0,
#  130.0,
#  7.0,
#  134.0,
#  20.0,
#  9.0,
#  5.0,
#  267.0,
#  26849.0,
#  38.0,
#  5.0,
#  42.0,
#  6933.0,
#  403.0,
#  156.0,
#  6.0,
#  68.0,
#  167.0,
#  132.0,
#  12.0,
#  10.0,
#  3.0,
#  72.0,
#  210.0,
#  99.0,
#  1893.0,
#  436.0,
#  3186.0,
#  91.0,
#  1515.0,
#  1131.0,
#  6557.0,
#  52.0,
#  1161.0,
#  40.0,
#  264.0,
#  29.0,
#  851.0,
#  289.0,
#  300.0,
#  69.0,
#  3.0,
#  48.0,
#  61.0,
#  17.0,
#  13.0,
#  21.0,
#  90.0,
#  234.0,
#  7.0,
#  14.0,
# ...

# %%
corona_dataset_aggregated["max_infection_rates"] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %% [markdown]
# ***Creating a New DataFrame with Maximum Infection Rates***
#
# ---

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["max_infection_rates"])

# %%
corona_data.head()
# Out:
#                 max_infection_rates
# Country/Region
# Afghanistan                   232.0
# Albania                        34.0
# Algeria                       199.0
# Andorra                        43.0
# Angola                          5.0

# %% [markdown]
# ***Importing the World Happiness Report Dataset***
#
# ---

# %% [markdown]
# ***Importing the Dataset***
#
# ---

# %%
happiness_report_csv = pd.read_csv("worldwide_happiness_report.csv")

# %%
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ***Dropping the Useless Columns***
#
# ---

# %%
useless_cols = ["Overall rank", "Score", "Generosity", "Perceptions of corruption"]

# %%
happiness_report_csv.drop(useless_cols, axis=1, inplace=True)
happiness_report_csv.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# ***Changing the Indices of the DataFrame***
#
# ---

# %%
happiness_report_csv.set_index("Country or region", inplace=True)

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# ***Joining the Two Prepared Datasets***
#
# ---

# %% [markdown]
# ***Covid 19 Dataset***
#
# ---

# %%
corona_data.head()
# Out:
#                 max_infection_rates
# Country/Region
# Afghanistan                   232.0
# Albania                        34.0
# Algeria                       199.0
# Andorra                        43.0
# Angola                          5.0

# %%
corona_data.shape    #Tuple with 187 countries
# Out:
# (187, 1)

# %% [markdown]
# ***World Happiness Report Dataset***
#
# ---

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
happiness_report_csv.shape
# Out:
# (156, 4)

# %%
#Inner join
data = corona_data.join(happiness_report_csv,
                how = "inner"    #method/type of join
                )
data.head()
# Out:
#              max_infection_rates  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ***Correlational Matrix***
#
# ---

# %%
data.corr()
# Out:
#                               max_infection_rates  GDP per capita  \
# max_infection_rates                      1.000000        0.250118
# GDP per capita                           0.250118        1.000000
# Social support                           0.191958        0.759468
# Healthy life expectancy                  0.289263        0.863062
# Freedom to make life choices             0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rates                 0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rates                               0.078196
# ...

# %% [markdown]
# There is +ve correlation between max_infection-rate and all other features

# %% [markdown]
# # ***Visualization of the Analysed Data***
#
# ---

# %%
data.head()
# Out:
#              max_infection_rates  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ***Plotting of GDP per capita vs Maximum Infection Rate***
#
# ---

# %% [markdown]
# **Normal Plotting of GDP per capita vs Maximum Infection Rate**

# %%
sns.scatterplot(data=data,x="GDP per capita",y="max_infection_rates")
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_infection_rates'>

# %% [markdown]
# **Logarithmic Plotting of GDP per capita vs Maximum Infection Rate**

# %%
sns.scatterplot(data=data,x="GDP per capita",y="max_infection_rates")
plt.yscale('log')

# %% [markdown]
# **Regional Plotting of GDP per capita vs Maximum Infection Rate**

# %%
sns.regplot(data=data,x="GDP per capita",y="max_infection_rates")
plt.yscale('log')

# %% [markdown]
# ***Plotting of Social Support vs Maximum Infection Rate***
#
# ---

# %% [markdown]
# **Normal Plotting of Social Support vs Maximum Infection Rate**

# %%
sns.scatterplot(data=data,x="Social support",y="max_infection_rates")
# Out:
# <Axes: xlabel='Social support', ylabel='max_infection_rates'>

# %% [markdown]
# **Logarithmic Plotting of Social Support vs Maximum Infection Rate**

# %%
sns.scatterplot(data=data,x="Social support",y="max_infection_rates")
plt.yscale('log')

# %% [markdown]
# **Regional Plotting of Social Support vs Maximum Infection Rate**

# %%
sns.regplot(data=data,x="Social support",y="max_infection_rates")
plt.yscale('log')

# %% [markdown]
# ***Plotting of Healthy Life expectancy vs Maximum Infection Rate***
#
# ---

# %% [markdown]
# **Normal Plotting of Healthy Life expectancy vs Maximum Infection Rate**

# %%
sns.scatterplot(data=data,x="Healthy life expectancy",y="max_infection_rates")
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max_infection_rates'>

# %% [markdown]
# **Logarithmic Plotting of Healthy Life expectancy vs Maximum Infection Rate**

# %%
sns.scatterplot(data=data,x="Healthy life expectancy",y="max_infection_rates")
plt.yscale('log')

# %% [markdown]
# **Regional Plotting of Healthy Life expectancy vs Maximum Infection Rate**

# %%
sns.regplot(data=data,x="Healthy life expectancy",y="max_infection_rates")
plt.yscale('log')

# %% [markdown]
# ***Plotting of Freedom to make life choices vs Maximum Infection Rate***
#
# ---

# %% [markdown]
# **Normal Plotting of Freedom to make life choices vs Maximum Infection Rate**

# %%
sns.scatterplot(data=data,x="Freedom to make life choices",y="max_infection_rates")
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='max_infection_rates'>

# %% [markdown]
# **Logarithmic Plotting of Freedom to make life choices vs Maximum Infection Rate**

# %%
sns.scatterplot(data=data,x="Freedom to make life choices",y="max_infection_rates")
plt.yscale('log')

# %% [markdown]
# **Regional Plotting of Freedom to make life choices vs Maximum Infection Rate**

# %%
sns.regplot(data=data,x="Freedom to make life choices",y="max_infection_rates")
plt.yscale('log')
